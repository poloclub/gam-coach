# %% [markdown]
# # GAM Coach: Binary Classification
#
# In this notebook, we will learn how to generate *diverse* and *customizable* counterfactual explanations for Generalized Additive Models (GAMs).

# %% [markdown]
# ## 2. Adult

# %%
# %load_ext autoreload
# %autoreload 2

import gamcoach as coach

import numpy as np
import pandas as pd

import dice_ml
import urllib.request
import json
import pickle

from interpret.glassbox import ExplainableBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from collections import Counter
from tqdm import tqdm

SEED = 101221

# %%
adult_data = pd.read_csv('./data/adult.data', header=None)
adult_data_test = pd.read_csv('./data/adult.test', header=None)

# From https://github.com/amirhk/mace/blob/01e6a405ff74e24dc3438a005cd60892154d189d/_data_main/fair_adult_data.py
adult_attrs = [
    "age",
    "workclass",
    "fnlwgt",
    "education",
    "education_num",
    "marital_status",
    "occupation",
    "relationship",
    "race",
    "sex",
    "capital_gain",
    "capital_loss",
    "hours_per_week",
    "native_country",
]

selected_features = [0, 1, 3, 4, 5, 6, 7, 9, 10, 11, 12, 13]

x_train = adult_data.to_numpy()[:, selected_features]

y_train_ints = list(map(lambda x: 0 if x == ' <=50K' else 1, adult_data.iloc[:, -1].tolist()))
y_train = np.array(y_train_ints)

x_test = adult_data_test.to_numpy()[:, selected_features]

y_test_ints = list(map(lambda x: 0 if x == ' <=50K.' else 1, adult_data_test.iloc[:, -1].tolist()))
y_test = np.array(y_test_ints)

adult_feature_names = np.array(adult_attrs)[selected_features]
adult_feature_names
adult_cont_indexes = [0, 3, 8, 9, 10]
adult_feature_types = [
    "continuous" if i in adult_cont_indexes else "categorical"
    for i in range(len(adult_feature_names))
]

# %%
# Train an EBM classifier
adult_ebm = ExplainableBoostingClassifier(
    feature_names=adult_feature_names,
    feature_types=adult_feature_types,
    random_state=SEED,
)
adult_ebm.fit(x_train, y_train)
# Out:
# ExplainableBoostingClassifier(feature_names=['age', 'workclass', 'education',
#                                              'education_num', 'marital_status',
#                                              'occupation', 'relationship',
#                                              'sex', 'capital_gain',
#                                              'capital_loss', 'hours_per_week',
#                                              'native_country',
#                                              'relationship x hours_per_week',
#                                              'age x relationship',
#                                              'age x capital_loss',
#                                              'marital_status x hours_per_week',
#                                              'relationship x capital_loss',
#                                              'education_num x o...
#                                              'workclass x relationship'],
#                               feature_types=['continuous', 'categorical',
#                                              'categorical', 'continuous',
#                                              'categorical', 'categorical',
#                                              'categorical', 'categorical',
#                                              'continuous', 'continuous',
#                                              'continuous', 'categorical',
#                                              'interaction', 'interaction',
#                                              'interaction', 'interaction',
#                                              'interaction', 'interaction',
#                                              'interaction', 'interaction',
#                                              'interaction', 'interaction'],
#                               random_state=101221)

# %%
# Evaluate our model

y_pred = adult_ebm.predict(x_test)
y_pred_prob = adult_ebm.predict_proba(x_test)[:, 1]

print(Counter(y_pred))
print()

accuracy = metrics.accuracy_score(y_test, y_pred)
auc = metrics.roc_auc_score(y_test, y_pred_prob)
f1 = metrics.f1_score(y_test, y_pred)
recall = metrics.recall_score(y_test, y_pred)
precision = metrics.precision_score(y_test, y_pred)
balanced_accuracy = metrics.balanced_accuracy_score(y_test, y_pred)

confusion_matrix = metrics.confusion_matrix(y_test, y_pred)

tn = confusion_matrix[0, 0]
fn = confusion_matrix[1, 0]
fp = confusion_matrix[0, 1]
tp = confusion_matrix[1, 1]
specificity = tn / (tn + fp)

temp = ('accuracy: {:.4f} \nauc: {:.4f} \nrecall:{:.4f} \nprecision: {:.4f} '+
    'specificity: {:.4f} \nf1: {:.4f}\nbalanced accuracy: {:.4f}')
print(temp.format(accuracy, auc, recall, precision, specificity, f1, balanced_accuracy))
print()

print('confusion matrix:\n', confusion_matrix)
# Out:
# Counter({0: 13103, 1: 3178})
#
# accuracy: 0.8727
# auc: 0.9256
# recall:0.6438
# precision: 0.7791 specificity: 0.9435
# f1: 0.7050
# balanced accuracy: 0.7937
#
# confusion matrix:
#  [[11733   702]
#  [ 1370  2476]]

# %%
# Find an interesting data point
# We can focus on test cases where our model rejcets the application (y_hat = 0)
reject_index = y_pred == 0
x_reject = x_test[reject_index, :]
y_pred_reject = y_pred[reject_index]

explain_df = pd.DataFrame(x_reject).sample(400)
explain_df.columns = adult_feature_names

reject_df = pd.DataFrame(np.hstack((x_reject, y_pred_reject.reshape(-1, 1))))
reject_df.columns = adult_feature_names.tolist() + ['prediction']
reject_df.head()
# Out:
#   age   workclass      education education_num       marital_status  \
# 0  25     Private           11th             7        Never-married
# 1  38     Private        HS-grad             9   Married-civ-spouse
# 2  28   Local-gov     Assoc-acdm            12   Married-civ-spouse
# 3  18           ?   Some-college            10        Never-married
# 4  34     Private           10th             6        Never-married
#
#            occupation    relationship      sex capital_gain capital_loss  \
# 0   Machine-op-inspct       Own-child     Male            0            0
# 1     Farming-fishing         Husband     Male            0            0
# 2     Protective-serv         Husband     Male            0            0
# 3                   ?       Own-child   Female            0            0
# 4       Other-service   Not-in-family     Male            0            0
#
#   hours_per_week  native_country prediction
# 0             40   United-States          0
# 1             50   United-States          0
# 2             40   United-States          0
# 3             30   United-States          0
# 4             30   United-States          0

# %%
def evaluate_cf(x1, x2, feature_names, cont_mads):
    cur_distance = 0
    feature_weight = 1 / len(feature_names)
    changed_feature = 0

    for i in range(len(feature_names)):
        cur_name = feature_names[i]

        # If the current feature is continuous
        if cur_name in cont_mads:
            if cont_mads[cur_name] > 0:
                cur_distance += (
                    feature_weight * abs(float(x2[i]) - float(x1[i])) / cont_mads[cur_name]
                )
            else:
                cur_distance += (
                    feature_weight * abs(float(x2[i]) - float(x1[i]))
                )
        else:
            cur_distance += 1 if x1[i] != x2[i] else 0

        if x1[i] != x2[i]:
            changed_feature += 1

    return cur_distance, changed_feature

# %% [markdown]
# ### 1.1. GAM Coach

# %%
features_to_vary = adult_feature_names
adult_feature_names
# Out:
# array(['age', 'workclass', 'education', 'education_num', 'marital_status',
#        'occupation', 'relationship', 'sex', 'capital_gain',
#        'capital_loss', 'hours_per_week', 'native_country'], dtype='<U14')

# %%
my_coach = coach.GAMCoach(adult_ebm, x_train, adjust_cat_distance=False)

cfs = []
for i in tqdm(range(explain_df.shape[0])):
# for i in tqdm(range(20)):

    try:
        cf = my_coach.generate_cfs(
            explain_df.iloc[i, :].to_numpy(),
            total_cfs=1,
            verbose=0,
            categorical_weight=1
            # Some continuous features need to have integer values in practice
            # continuous_integer_features=["open_acc", "total_acc", "mort_acc", "fico_score"],
        )

        cfs.append([explain_df.iloc[i, :], cf.to_df().iloc[0, :]])
    except:
        cfs.append(None)
# Out:
# 100%|██████████| 400/400 [07:52<00:00,  1.18s/it]

# %%
pickle.dump(cfs, open('./data/adult-coach-cfs.pkl', 'wb'))

# %%
distances, feature_nums, failed_indexes = [], [], []

for i in range(len(cfs)):
    if cfs[i] is None:
        failed_indexes.append(i)
        continue

    x1 = cfs[i][0]
    x2 = cfs[i][1][:-1]

    cur_distance, changed_feature = evaluate_cf(x1, x2, adult_feature_names, my_coach.cont_mads)
    
    distances.append(cur_distance)
    feature_nums.append(changed_feature)

# %%
print(
    "coach",
    "\ndistance: ",
    np.mean(distances),
    "\nnum: ",
    np.mean(feature_nums),
    "\nfails: ",
    len(failed_indexes),
)
# Out:
# coach
# distance:  1.6855904527777779
# num:  2.4075
# fails:  0

# %% [markdown]
# ### 1.2. Genetic Algorithm

# %%
dice_df = pd.DataFrame(x_train)
dice_df.columns = adult_feature_names
dice_df['status'] = y_train

feature_names_cont = adult_feature_names[adult_cont_indexes].tolist()

for c in feature_names_cont:
    dice_df[c] = dice_df[c].astype(float)

dice_data = dice_ml.Data(
    dataframe=dice_df,
    continuous_features=feature_names_cont,
    outcome_name='status'
)

dice_model = dice_ml.Model(model=adult_ebm, backend='sklearn')

# %%
exp = dice_ml.Dice(dice_data, dice_model, method='genetic')

dice_rejected_df = explain_df.copy()
for c in feature_names_cont:
    dice_rejected_df[c] = dice_rejected_df[c].astype(float)

explanation_generic = exp.generate_counterfactuals(
    dice_rejected_df,
    total_CFs=1,
    features_to_vary=features_to_vary.tolist(),
    # posthoc_sparsity_param=0.2,
    verbose=False,
    desired_class="opposite")
# Out:
#   0%|          | 0/400 [00:00<?, ?it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   0%|          | 1/400 [00:00<05:26,  1.22it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   0%|          | 2/400 [00:01<05:21,  1.24it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   1%|          | 3/400 [00:02<05:15,  1.26it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   1%|          | 4/400 [00:03<04:59,  1.32it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   1%|▏         | 5/400 [00:03<04:52,  1.35it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   2%|▏         | 6/400 [00:04<04:48,  1.37it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   2%|▏         | 7/400 [00:05<04:47,  1.37it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   2%|▏         | 8/400 [00:06<04:49,  1.35it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   2%|▏         | 9/400 [00:06<04:43,  1.38it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   2%|▎         | 10/400 [00:07<04:39,  1.40it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   3%|▎         | 11/400 [00:08<04:33,  1.42it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   3%|▎         | 12/400 [00:08<04:36,  1.40it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   3%|▎         | 13/400 [00:09<04:35,  1.40it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   4%|▎         | 14/400 [00:10<04:36,  1.40it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   4%|▍         | 15/400 [00:10<04:31,  1.42it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   4%|▍         | 16/400 [00:11<04:34,  1.40it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   4%|▍         | 17/400 [00:12<04:36,  1.38it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   4%|▍         | 18/400 [00:13<04:32,  1.40it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   5%|▍         | 19/400 [00:13<04:27,  1.42it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   5%|▌         | 20/400 [00:14<04:25,  1.43it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   5%|▌         | 21/400 [00:15<04:23,  1.44it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   6%|▌         | 22/400 [00:15<04:21,  1.44it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   6%|▌         | 23/400 [00:16<04:18,  1.46it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   6%|▌         | 24/400 [00:17<04:15,  1.47it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   6%|▋         | 25/400 [00:17<04:25,  1.41it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   6%|▋         | 26/400 [00:18<04:37,  1.35it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   7%|▋         | 27/400 [00:19<05:01,  1.24it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   7%|▋         | 28/400 [00:20<05:01,  1.23it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   7%|▋         | 29/400 [00:21<04:55,  1.26it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   8%|▊         | 30/400 [00:22<04:46,  1.29it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   8%|▊         | 31/400 [00:22<04:42,  1.30it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   8%|▊         | 32/400 [00:23<04:33,  1.35it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   8%|▊         | 33/400 [00:24<04:27,  1.37it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   8%|▊         | 34/400 [00:24<04:25,  1.38it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   9%|▉         | 35/400 [00:25<04:26,  1.37it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#
  1.44it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  95%|█████████▌| 381/400 [04:30<00:13,  1.46it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  96%|█████████▌| 382/400 [04:31<00:12,  1.44it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  96%|█████████▌| 383/400 [04:31<00:11,  1.44it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  96%|█████████▌| 384/400 [04:32<00:10,  1.47it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  96%|█████████▋| 385/400 [04:33<00:10,  1.46it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  96%|█████████▋| 386/400 [04:34<00:09,  1.44it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  97%|█████████▋| 387/400 [04:34<00:09,  1.42it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  97%|█████████▋| 388/400 [04:35<00:08,  1.43it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  97%|█████████▋| 389/400 [04:36<00:07,  1.43it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  98%|█████████▊| 390/400 [04:36<00:06,  1.45it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  98%|█████████▊| 391/400 [04:37<00:06,  1.45it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  98%|█████████▊| 392/400 [04:38<00:05,  1.46it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  98%|█████████▊| 393/400 [04:38<00:04,  1.47it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  98%|█████████▊| 394/400 [04:39<00:04,  1.47it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  99%|█████████▉| 395/400 [04:40<00:03,  1.48it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  99%|█████████▉| 396/400 [04:40<00:02,  1.49it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  99%|█████████▉| 397/400 [04:41<00:02,  1.44it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
# 100%|█████████▉| 398/400 [04:42<00:01,  1.45it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
# 100%|█████████▉| 399/400 [04:42<00:00,  1.44it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
# 100%|██████████| 400/400 [04:43<00:00,  1.41it/s]

# %%
g_distances, g_feature_nums, g_failed_indexes = [], [], []

for i in range(len(explanation_generic.cf_examples_list)):
    if explanation_generic.cf_examples_list[i].final_cfs_df is None:
        g_failed_indexes.append(i)
        continue

    x1 = dice_rejected_df.iloc[i, :]
    x2 = explanation_generic.cf_examples_list[i].final_cfs_df.iloc[0, :]

    cur_distance, changed_feature = evaluate_cf(x1, x2, adult_feature_names, my_coach.cont_mads)
    
    g_distances.append(cur_distance)
    g_feature_nums.append(changed_feature)

# %%
print(
    "generic",
    "\ndistance: ",
    np.mean(g_distances),
    "\nnum: ",
    np.mean(g_feature_nums),
    "\nfails: ",
    len(g_failed_indexes),
)
# Out:
# generic
# distance:  4.923069444444444
# num:  4.6475
# fails:  0

# %% [markdown]
# ### KD Tree

# %%
exp = dice_ml.Dice(dice_data, dice_model, method='kdtree')

dice_rejected_df = explain_df.copy()
for c in feature_names_cont:
    dice_rejected_df[c] = dice_rejected_df[c].astype(float)

explanation_tree = exp.generate_counterfactuals(
    dice_rejected_df,
    total_CFs=1,
    features_to_vary=features_to_vary.tolist(),
    # posthoc_sparsity_param=0.2,
    verbose=False,
    desired_class="opposite")
# Out:
#   0%|          | 0/400 [00:00<?, ?it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   0%|          | 1/400 [00:00<05:05,  1.31it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   0%|          | 2/400 [00:01<04:56,  1.34it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   1%|          | 3/400 [00:02<04:39,  1.42it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   1%|          | 4/400 [00:02<04:31,  1.46it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   1%|▏         | 5/400 [00:03<04:32,  1.45it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   2%|▏         | 6/400 [00:04<04:34,  1.44it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   2%|▏         | 7/400 [00:05<04:59,  1.31it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   2%|▏         | 8/400 [00:05<04:44,  1.38it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   2%|▏         | 9/400 [00:06<04:39,  1.40it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   2%|▎         | 10/400 [00:07<04:29,  1.45it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   3%|▎         | 11/400 [00:07<04:26,  1.46it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   3%|▎         | 12/400 [00:08<04:23,  1.47it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   3%|▎         | 13/400 [00:09<04:18,  1.50it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   4%|▎         | 14/400 [00:09<04:16,  1.51it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   4%|▍         | 15/400 [00:10<04:12,  1.52it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   4%|▍         | 16/400 [00:11<04:13,  1.52it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   4%|▍         | 17/400 [00:11<04:09,  1.54it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   4%|▍         | 18/400 [00:12<04:07,  1.54it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   5%|▍         | 19/400 [00:12<04:05,  1.55it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   5%|▌         | 20/400 [00:13<04:07,  1.53it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   5%|▌         | 21/400 [00:14<04:05,  1.54it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   6%|▌         | 22/400 [00:14<04:06,  1.53it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   6%|▌         | 23/400 [00:15<04:03,  1.55it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   6%|▌         | 24/400 [00:16<04:01,  1.56it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#   6%|▋         | 25/400 [00:16<04:03,  1.54it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#
/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  89%|████████▉ | 357/400 [04:13<00:32,  1.34it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  90%|████████▉ | 358/400 [04:13<00:30,  1.37it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  90%|████████▉ | 359/400 [04:14<00:28,  1.42it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  90%|█████████ | 360/400 [04:15<00:27,  1.44it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  90%|█████████ | 361/400 [04:15<00:26,  1.48it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  90%|█████████ | 362/400 [04:16<00:25,  1.50it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  91%|█████████ | 363/400 [04:17<00:25,  1.48it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  91%|█████████ | 364/400 [04:17<00:23,  1.51it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  91%|█████████▏| 365/400 [04:18<00:23,  1.49it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  92%|█████████▏| 366/400 [04:19<00:23,  1.44it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  92%|█████████▏| 367/400 [04:19<00:22,  1.48it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  92%|█████████▏| 368/400 [04:20<00:21,  1.51it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  92%|█████████▏| 369/400 [04:21<00:20,  1.52it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  92%|█████████▎| 370/400 [04:21<00:19,  1.53it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  93%|█████████▎| 371/400 [04:22<00:18,  1.56it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  93%|█████████▎| 372/400 [04:22<00:17,  1.56it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  93%|█████████▎| 373/400 [04:23<00:17,  1.51it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  94%|█████████▎| 374/400 [04:24<00:17,  1.52it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  94%|█████████▍| 375/400 [04:24<00:16,  1.53it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  94%|█████████▍| 376/400 [04:25<00:15,  1.52it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  94%|█████████▍| 377/400 [04:26<00:15,  1.50it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  94%|█████████▍| 378/400 [04:26<00:14,  1.52it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  95%|█████████▍| 379/400 [04:27<00:13,  1.52it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  95%|█████████▌| 380/400 [04:28<00:12,  1.54it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  95%|█████████▌| 381/400 [04:28<00:12,  1.50it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  96%|█████████▌| 382/400 [04:29<00:11,  1.53it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  96%|█████████▌| 383/400 [04:30<00:11,  1.54it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  96%|█████████▌| 384/400 [04:30<00:10,  1.55it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  96%|█████████▋| 385/400 [04:31<00:09,  1.54it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  96%|█████████▋| 386/400 [04:32<00:09,  1.54it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  97%|█████████▋| 387/400 [04:32<00:08,  1.53it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  97%|█████████▋| 388/400 [04:33<00:07,  1.52it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  97%|█████████▋| 389/400 [04:34<00:07,  1.48it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  98%|█████████▊| 390/400 [04:34<00:06,  1.52it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  98%|█████████▊| 391/400 [04:35<00:05,  1.54it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  98%|█████████▊| 392/400 [04:36<00:05,  1.55it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  98%|█████████▊| 393/400 [04:36<00:04,  1.51it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  98%|█████████▊| 394/400 [04:37<00:03,  1.52it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  99%|█████████▉| 395/400 [04:38<00:03,  1.52it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  99%|█████████▉| 396/400 [04:38<00:02,  1.51it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
#  99%|█████████▉| 397/400 [04:39<00:01,  1.53it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
# 100%|█████████▉| 398/400 [04:39<00:01,  1.54it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
# 100%|█████████▉| 399/400 [04:40<00:00,  1.48it/s]WARNING:root: MAD for feature capital_gain is 0, so replacing it with 1.0 to avoid error.
# WARNING:root: MAD for feature capital_loss is 0, so replacing it with 1.0 to avoid error.
# 100%|██████████| 400/400 [04:41<00:00,  1.42it/s]

# %%
k_distances, k_feature_nums, k_failed_indexes = [], [], []

for i in range(len(explanation_tree.cf_examples_list)):
    if explanation_tree.cf_examples_list[i].final_cfs_df is None:
        k_failed_indexes.append(i)
        continue

    if explanation_tree.cf_examples_list[i].final_cfs_df.shape == (0, 0):
        k_failed_indexes.append(i)
        continue

    x1 = dice_rejected_df.iloc[i, :]
    x2 = explanation_tree.cf_examples_list[i].final_cfs_df.iloc[0, :]

    cur_distance, changed_feature = evaluate_cf(x1, x2, adult_feature_names, my_coach.cont_mads)
    
    k_distances.append(cur_distance)
    k_feature_nums.append(changed_feature)

# %%
print(
    "tree",
    "\ndistance: ",
    np.mean(k_distances),
    "\nnum: ",
    np.mean(k_feature_nums),
    "\nfails: ",
    len(k_failed_indexes),
)
# Out:
# tree
# distance:  5.108152777777778
# num:  4.95
# fails:  0
